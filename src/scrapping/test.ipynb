# %%
import pandas as pd

# %%
depot = ""
depot_addresses = pd.read_csv("../../data/depot_data/depots.csv").set_index("Depot")
depot_address = depot_addresses.loc[' ' + depot]["Address"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f7d9c2e174a2> in <module>
#       1 depot_addresses = pd.read_csv("../../data/depot_data/depots.csv").set_index("Depot")
# ----> 2 depot_address = depot_addresses.loc[' ' + depot]["Address"]
#
# NameError: name 'depot' is not defined

# %%
depot_addresses
# Out:
#                                             Borough  \
# Depot
#  Eastchester Depot (EC)                       Bronx
#  Gun Hill Depot (GH)                          Bronx
#  Kingsbridge Depot (KB)                       Bronx
#  West Farms Depot (WF)                        Bronx
#  Yonkers Depot (YO)                           Bronx
#  Zerega Central Maintenance Facility          Bronx
#  Amsterdam Facility (AM)                  Manhattan
#  Manhattanville Depot (MV)                Manhattan
#  Michael J. Quill Depot (MQ)              Manhattan
#  Mother Clara Hale Depot (OF)             Manhattan
#  Tuskegee Airmen Depot (OH)               Manhattan
#  Baisley Park Depot (BP)                     Queens
#  Casey Stengel Depot (CS)                    Queens
#  College Point Depot (CP)                    Queens
#  Far Rockaway Depot (FR)                     Queens
#  Jamaica Depot (JA)                          Queens
#  JFK Depot (JK)                              Queens
#  LaGuardia Depot (LG)                        Queens
#  Queens Village Depot (QV)                   Queens
#  Spring Creek Depot (SC)                     Queens
#  East New York Depot & CMF (EN)            Brooklyn
#  Flatbush Depot (FB)                       Brooklyn
#  Fresh Pond Depot (FP)                     Brooklyn
#  Grand Avenue Depot & CMF (GA)             Brooklyn
#  Jackie Gleason Depot (JG)                 Brooklyn
#  Ulmer Park Depot (UP)                     Brooklyn
#  Castleton Depot (CA)                 Staten Island
#  Charleston Depot (CH)                Staten Island
#  Meredith Avenue Depot (MA)           Staten Island
#  Yukon Depot (YU)                     Staten Island
#
#                                                                                 Address  \
# Depot
#  Eastchester Depot (EC)                              3320 Tillotson Av, Bronx, NY 10475
#  Gun Hill Depot (GH)                                    1910 Bartow Av, Bronx, NY 10469
#  Kingsbridge Depot (KB)                                4065 10th Av, New York, NY 10034
#  West Farms Depot (WF)                Bronx Division Headquarters, 1100 E 177th St, ...
#  Yonkers Depot (YO)                                    59 Babcock Pl, Yonkers, NY 10701
#  Zerega Central Maintenance Facility  MTA Bus Operations, 750-770 Zerega Av, Bronx, ...
#  Amsterdam Facility (AM)                          1381 Amsterdam Av, New York, NY 10027
#  Manhattanville Depot (MV)                           666 W 133rd St, New York, NY 10027
#  Michael J. Quill Depot (MQ)          Manhattan Headquarters, 525 11th Av, New York,...
#  Mother Clara Hale Depot (OF)                          721 Lenox Av, New York, NY 10039
#  Tuskegee Airmen Depot (OH)                       1552 Lexington Av, New York, NY 10029
#  Baisley Park Depot (BP)                            114-15 Brewer Bl, Jamaica, NY 11434
#  Casey Stengel Depot (CS)                         123-53 Roosevelt Av, Corona, NY 11368
#  College Point Depot (CP)                            128-15 28th Av, Flushing, NY 11354
#  Far Rockaway Depot (FR)                  49-19 Rockaway Bch Bl, Far Rockaway, NY 11691
#  Jamaica Depot (JA)                        165-18 Tuskegee Airmen Way Jamaica, NY 11433
#  JFK Depot (JK)                       Queens South Headquarters, 165-25 147th Av, Ja...
#  LaGuardia Depot (LG)                            85-01 24th Av, East Elmhurst, NY 11370
#  Queens Village Depot (QV)            Queens North Headquarters, 222-22 97th Avenue,...
#  Spring Creek Depot (SC)                         12755 Flatlands Av, Brooklyn, NY 11208
#  East New York Depot & CMF (EN)       Central Maintenance Facility, MTA Bus Operatio...
#  Flatbush Depot (FB)                               4901 Fillmore Av, Brooklyn, NY 11234
#  Fresh Pond Depot (FP)                Brooklyn Headquarters, 66-99 Fresh Pond Rd, Ri...
#  Grand Avenue Depot & CMF (GA)        Central Maintenance Facility, 48-05 Grand Av, ...
#  Jackie Gleason Depot (JG)                               845 5th Av, Brooklyn, NY 11232
#  Ulmer Park Depot (UP)                               2449 Harway Av, Brooklyn, NY 11214
#  Castleton Depot (CA)                    1390 Castleton Avenue, Staten Island, NY 10310
#  Charleston Depot (CH)                   4700 Arthur Kill Road, Staten Island, NY 10309
#  Meredith Avenue Depot (MA)                336 Meredith Avenue, Staten Island, NY 10314
#  Yukon Depot (YU)                     Staten Island Headquarters, 40 Yukon Avenue, S...
#
#                                       Total buses
# Depot
#  Eastchester Depot (EC)                       142
#  Gun Hill Depot (GH)                          284
#  Kingsbridge Depot (KB)                       272
#  West Farms Depot (WF)                        321
#  Yonkers Depot (YO)                            84
#  Zerega Central Maintenance Facility            2
#  Amsterdam Facility (AM)                       27
#  Manhattanville Depot (MV)                    240
#  Michael J. Quill Depot (MQ)                  298
#  Mother Clara Hale Depot (OF)                 137
#  Tuskegee Airmen Depot (OH)                   148
#  Baisley Park Depot (BP)                      116
#  Casey Stengel Depot (CS)                     231
#  College Point Depot (CP)                     330
#  Far Rockaway Depot (FR)                       45
#  Jamaica Depot (JA)                           202
#  JFK Depot (JK)                               243
#  LaGuardia Depot (LG)                         254
#  Queens Village Depot (QV)                    284
#  Spring Creek Depot (SC)                      126
#  East New York Depot & CMF (EN)               242
#  Flatbush Depot (FB)                          239
#  Fresh Pond Depot (FP)                        224
#  Grand Avenue Depot & CMF (GA)                185
#  Jackie Gleason Depot (JG)                    302
#  Ulmer Park Depot (UP)                        251
#  Castleton Depot (CA)                         230
#  Charleston Depot (CH)                        203
#  Meredith Avenue Depot (MA)                    74
#  Yukon Depot (YU)                             265
